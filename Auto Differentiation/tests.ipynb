# %% [markdown]
# # Test Auto Differentiation Library
#
# Tests both a forward and backward pass of a single node and of the whole graph

# %%
# !pytest tests/test_auto_diff_node_forward.py
# !pytest tests/test_auto_diff_node_backward.py
# !pytest tests/test_auto_diff_graph_forward.py
# !pytest tests/test_auto_diff_graph_backward.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# Fugue tests will be initialized with options:
# rootdir: /Users/caseyhild/Downloads/CSE 234/Auto Differentiation
# plugins: anyio-3.5.0, fugue-0.9.1
# collected 28 items
#
# tests/test_auto_diff_node_forward.py ............................        [100%]
#
# ============================== 28 passed in 0.89s ==============================
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# Fugue tests will be initialized with options:
# rootdir: /Users/caseyhild/Downloads/CSE 234/Auto Differentiation
# plugins: anyio-3.5.0, fugue-0.9.1
# collected 28 items
#
# tests/test_auto_diff_node_backward.py ............................       [100%]
#
# ============================== 28 passed in 0.64s ==============================
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# Fugue tests will be initialized with options:
# rootdir: /Users/caseyhild/Downloads/CSE 234/Auto Differentiation
# plugins: anyio-3.5.0, fugue-0.9.1
# collected 9 items
#
# tests/test_auto_diff_graph_forward.py .........                          [100%]
#
# ============================== 9 passed in 0.62s ===============================
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# Fugue tests will be initialized with options:
# rootdir: /Users/caseyhild/Downloads/CSE 234/Auto Differentiation
# plugins: anyio-3.5.0, fugue-0.9.1
# collected 2 items
#
# tests/test_auto_diff_graph_backward.py ..                                [100%]
#
# ============================== 2 passed in 0.62s ===============================

# %% [markdown]
# # Test Fused Ops
#
# Tests both a forward and backward pass as well as the performance of the fused operations

# %%
# !pytest tests/test_fused_ops.py
# !python tests/test_fused_ops_perf.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# Fugue tests will be initialized with options:
# rootdir: /Users/caseyhild/Downloads/CSE 234/Auto Differentiation
# plugins: anyio-3.5.0, fugue-0.9.1
# collected 4 items
#
# tests/test_fused_ops.py ....                                             [100%]
#
# ============================== 4 passed in 0.66s ===============================
#
# ================================================================================
# Running benchmark: 2D Matrix Multiplication
# ================================================================================
#
# Testing shapes: (128, 64) @ (64, 128)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    0.035 ms ± 0.009 ms
# Unfused:  0.033 ms ± 0.006 ms
# Speedup:  0.93x
#
# Backward Pass:
# Fused:    0.108 ms ± 0.018 ms
# Unfused:  0.134 ms ± 0.013 ms
# Speedup:  1.25x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    0.041 ms ± 0.020 ms
# Unfused:  0.033 ms ± 0.007 ms
# Speedup:  0.81x
#
# Backward Pass:
# Fused:    0.091 ms ± 0.042 ms
# Unfused:  0.105 ms ± 0.045 ms
# Speedup:  1.15x
#
# Testing shapes: (512, 256) @ (256, 512)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    0.251 ms ± 0.080 ms
# Unfused:  0.252 ms ± 0.122 ms
# Speedup:  1.00x
#
# Backward Pass:
# Fused:    1.308 ms ± 0.289 ms
# Unfused:  1.588 ms ± 0.343 ms
# Speedup:  1.21x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    0.363 ms ± 0.144 ms
# Unfused:  0.347 ms ± 0.115 ms
# Speedup:  0.96x
#
# Backward Pass:
# Fused:    0.897 ms ± 0.229 ms
# Unfused:  1.126 ms ± 0.194 ms
# Speedup:  1.25x
#
# Testing shapes: (1024, 512) @ (512, 1024)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    2.016 ms ± 0.311 ms
# Unfused:  1.980 ms ± 0.283 ms
# Speedup:  0.98x
#
# Backward Pass:
# Fused:    7.829 ms ± 0.561 ms
# Unfused:  9.233 ms ± 0.945 ms
# Speedup:  1.18x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    2.342 ms ± 0.306 ms
# Unfused:  2.395 ms ± 0.228 ms
# Speedup:  1.02x
#
# Backward Pass:
# Fused:    6.085 ms ± 0.579 ms
# Unfused:  7.151 ms ± 0.974 ms
# Speedup:  1.18x
#
# ================================================================================
# Running benchmark: 3D Batch Matrix Multiplication
# ================================================================================
#
# Testing shapes: (32, 128, 64) @ (32, 64, 128)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    1.027 ms ± 0.215 ms
# Unfused:  1.042 ms ± 0.121 ms
# Speedup:  1.01x
#
# Backward Pass:
# Fused:    3.278 ms ± 0.450 ms
# Unfused:  3.975 ms ± 0.565 ms
# Speedup:  1.21x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    1.273 ms ± 0.385 ms
# Unfused:  1.265 ms ± 0.205 ms
# Speedup:  0.99x
#
# Backward Pass:
# Fused:    2.419 ms ± 0.545 ms
# Unfused:  3.350 ms ± 0.755 ms
# Speedup:  1.38x
#
# Testing shapes: (64, 256, 128) @ (64, 128, 256)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    8.694 ms ± 0.880 ms
# Unfused:  9.208 ms ± 2.791 ms
# Speedup:  1.06x
#
# Backward Pass:
# Fused:    25.441 ms ± 1.490 ms
# Unfused:  29.684 ms ± 1.249 ms
# Speedup:  1.17x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    9.988 ms ± 0.601 ms
# Unfused:  9.920 ms ± 0.682 ms
# Speedup:  0.99x
#
# Backward Pass:
# Fused:    21.070 ms ± 1.315 ms
# Unfused:  26.346 ms ± 4.249 ms
# Speedup:  1.25x
#
# Testing shapes: (128, 512, 256) @ (128, 256, 512)
#
# Testing MatMul + LayerNorm:
#
# Forward Pass:
# Fused:    85.204 ms ± 15.857 ms
# Unfused:  87.308 ms ± 6.457 ms
# Speedup:  1.02x
#
# Backward Pass:
# Fused:    238.791 ms ± 9.273 ms
# Unfused:  290.587 ms ± 11.390 ms
# Speedup:  1.22x
#
# Testing MatMul + Softmax:
#
# Forward Pass:
# Fused:    89.788 ms ± 9.312 ms
# Unfused:  88.653 ms ± 7.335 ms
# Speedup:  0.99x
#
# Backward Pass:
# Fused:    211.569 ms ± 11.688 ms
# Unfused:  259.654 ms ± 15.585 ms
# Speedup:  1.23x
